# %% [markdown]
# # Part 2, xgboost

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

from itertools import product
from sklearn.preprocessing import LabelEncoder

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from xgboost import XGBRegressor
from xgboost import plot_importance

def plot_features(booster, figsize):    
    fig, ax = plt.subplots(1,1,figsize=figsize)
    return plot_importance(booster=booster, ax=ax)

import time
import sys
import gc
import pickle
sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=5, releaselevel='final', serial=0)

# %%
data = pd.read_pickle('./data.pkl')

# %%
data = data[[
    'date_block_num',
    'shop_id',
    'item_id',
    'item_cnt_month',
    #'city_code',
    'item_category_id',
    'type_code',
    'subtype_code',
    'item_cnt_month_lag_1',
    'item_cnt_month_lag_2',
    'item_cnt_month_lag_3',
    'item_cnt_month_lag_6',
    #'item_cnt_month_lag_12',
    'date_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_1',
    'date_item_avg_item_cnt_lag_2',
    'date_item_avg_item_cnt_lag_3',
    'date_item_avg_item_cnt_lag_6',
    #'date_item_avg_item_cnt_lag_12',
    'date_shop_avg_item_cnt_lag_1',
    'date_shop_avg_item_cnt_lag_2',
    'date_shop_avg_item_cnt_lag_3',
    'date_shop_avg_item_cnt_lag_6',
    #'date_shop_avg_item_cnt_lag_12',
    'date_cat_avg_item_cnt_lag_1',
    'date_shop_cat_avg_item_cnt_lag_1',
    #'date_shop_type_avg_item_cnt_lag_1',
    #'date_shop_subtype_avg_item_cnt_lag_1',
    'date_city_avg_item_cnt_lag_1',
    'date_item_city_avg_item_cnt_lag_1',
    #'date_type_avg_item_cnt_lag_1',
    #'date_subtype_avg_item_cnt_lag_1',
    'delta_price_lag',
    'month',
    #'days',
    'item_shop_last_sale',
    'item_last_sale',
    'item_shop_first_sale',
    'item_first_sale',
]]

# %%
X_train = data[data.date_block_num < 33].drop(['item_cnt_month'], axis=1)
Y_train = data[data.date_block_num < 33]['item_cnt_month']
X_valid = data[data.date_block_num == 33].drop(['item_cnt_month'], axis=1)
Y_valid = data[data.date_block_num == 33]['item_cnt_month']
X_test = data[data.date_block_num == 34].drop(['item_cnt_month'], axis=1)

# %%
del data
gc.collect();

# %%
ts = time.time()

model = XGBRegressor(
    max_depth=8,
    n_estimators=1000,
    min_child_weight=300, 
    colsample_bytree=0.8, 
    subsample=0.8, 
    eta=0.3,    
    seed=42)

model.fit(
    X_train, 
    Y_train, 
    eval_metric="rmse", 
    eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
    verbose=True, 
    early_stopping_rounds = 20)

time.time() - ts
# Out:
# [10:52:20] Tree method is automatically selected to be 'approx' for faster speed. to use old behavior(exact greedy algorithm on single machine), set tree_method to 'exact'
# [0]	validation_0-rmse:1.15271	validation_1-rmse:1.12057
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:1.1048	validation_1-rmse:1.08272
# [2]	validation_0-rmse:1.06531	validation_1-rmse:1.05323
# [3]	validation_0-rmse:1.03223	validation_1-rmse:1.02932
# [4]	validation_0-rmse:1.00215	validation_1-rmse:1.00674
# [5]	validation_0-rmse:0.978147	validation_1-rmse:0.989509
# [6]	validation_0-rmse:0.957484	validation_1-rmse:0.97571
# [7]	validation_0-rmse:0.939119	validation_1-rmse:0.962875
# [8]	validation_0-rmse:0.923772	validation_1-rmse:0.952859
# [9]	validation_0-rmse:0.910696	validation_1-rmse:0.944414
# [10]	validation_0-rmse:0.899562	validation_1-rmse:0.937681
# [11]	validation_0-rmse:0.89072	validation_1-rmse:0.933024
# [12]	validation_0-rmse:0.882011	validation_1-rmse:0.927921
# [13]	validation_0-rmse:0.874864	validation_1-rmse:0.923679
# [14]	validation_0-rmse:0.86846	validation_1-rmse:0.919363
# [15]	validation_0-rmse:0.863469	validation_1-rmse:0.917467
# [16]	validation_0-rmse:0.859103	validation_1-rmse:0.915732
# [17]	validation_0-rmse:0.855221	validation_1-rmse:0.913704
# [18]	validation_0-rmse:0.851656	validation_1-rmse:0.912807
# [19]	validation_0-rmse:0.847808	validation_1-rmse:0.912053
# [20]	validation_0-rmse:0.844636	validation_1-rmse:0.910513
# [21]	validation_0-rmse:0.842009	validation_1-rmse:0.910462
# [22]	validation_0-rmse:0.839306	validation_1-rmse:0.910786
# [23]	validation_0-rmse:0.837112	validation_1-rmse:0.911068
# [24]	validation_0-rmse:0.834753	validation_1-rmse:0.911029
# [25]	validation_0-rmse:0.832905	validation_1-rmse:0.910077
# [26]	validation_0-rmse:0.831149	validation_1-rmse:0.910004
# [27]	validation_0-rmse:0.829259	validation_1-rmse:0.909705
# [28]	validation_0-rmse:0.827864	validation_1-rmse:0.909329
# [29]	validation_0-rmse:0.826572	validation_1-rmse:0.909326
# [30]	validation_0-rmse:0.824921	validation_1-rmse:0.909061
# [31]	validation_0-rmse:0.823918	validation_1-rmse:0.90889
# [32]	validation_0-rmse:0.822824	validation_1-rmse:0.909175
# [33]	validation_0-rmse:0.821912	validation_1-rmse:0.908989
# [34]	validation_0-rmse:0.820785	validation_1-rmse:0.909404
# [35]	validation_0-rmse:0.819874	validation_1-rmse:0.909314
# [36]	validation_0-rmse:0.819046	validation_1-rmse:0.909906
# [37]	validation_0-rmse:0.818221	validation_1-rmse:0.909943
# [38]	validation_0-rmse:0.817421	validation_1-rmse:0.909582
# [39]	validation_0-rmse:0.816518	validation_1-rmse:0.909533
# [40]	validation_0-rmse:0.815917	validation_1-rmse:0.909661
# [41]	validation_0-rmse:0.815414	validation_1-rmse:0.909251
# Stopping. Best iteration:
# [31]	validation_0-rmse:0.823918	validation_1-rmse:0.90889
# 765.203889131546

# %%
test  = pd.read_csv('./dataset/test.csv').set_index('ID')

# %%
Y_pred = model.predict(X_valid).clip(0, 20)
Y_test = model.predict(X_test).clip(0, 20)

submission = pd.DataFrame({
    "ID": test.index, 
    "item_cnt_month": Y_test
})
submission.to_csv('xgb_submission.csv', index=False)

# save predictions for an ensemble
pickle.dump(Y_pred, open('xgb_train.pickle', 'wb'))
pickle.dump(Y_test, open('xgb_test.pickle', 'wb'))

# %%
plot_features(model, (10,14))
